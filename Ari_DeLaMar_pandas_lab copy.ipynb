# %% [markdown]
# # Analyze Genre by Year
#
# We are data analysts at the streaming service `Metpicks`. This company specializes in media from 1990 - 2005. To gain more insight into the average rating and runtime of different media types. we will be analyzing the dataframe `imdb_processed.csv` dataset.
#
# Implement each line of pseudocode in each respective code-block, and then utilize your outputs to answer questions 1 through 4.
#
# If you are stuck on any line of pseudocde, be sure to utilize stackoverflow and google. This will be submitted via google classroom.

# %%
import pandas as pd

# read in your imdb_processed csv into a dataframe
df = pd.read_csv("../data/imdb_processed.csv")

# %%
# print out the first 5 rows of this dataframe
df.head()
# Out:
#    index                                              title  year  \
# 0      0                                    Dinosaur Planet  2003
# 1      1                                  Get Up and Dance!  1994
# 2      2                                              8 Man  1992
# 3      3                       What the #$*! Do We (K)now!?  2004
# 4      4  Class of Nuke 'Em High Part II: Subhumanoid Me...  1991
#
#              kind                                              genre  rating  \
# 0  tv mini series             ['Documentary', 'Animation', 'Family']     7.7
# 1     video movie                                         ['Family']     8.1
# 2           movie                               ['Action', 'Sci-Fi']     5.5
# 3           movie  ['Documentary', 'Comedy', 'Drama', 'Fantasy', ...     5.3
# 4           movie                     ['Comedy', 'Horror', 'Sci-Fi']     4.5
#
#       vote            country                          language  \
# 0    474.0  ['United States']                       ['English']
# 1     18.0  ['United States']                       ['English']
# 2     93.0          ['Japan']                      ['Japanese']
# 3  13432.0  ['United States']  ['English', 'German', 'Spanish']
# 4   2177.0  ['United States']                       ['English']
#
#                                                 cast  \
# 0              ['Christian Slater', 'Scott Sampson']
# 1  ['Paula Abdul', 'Aurorah Allain', 'Bill Bohl',...
# 2  ['Kai Shishido', 'Etsushi Takahashi', 'Sachiko...
# 3  ['Marlee Matlin', 'Elaine Hendrix', 'John Ross...
# 4  ['Brick Bronsky', 'Lisa Gaye', 'Leesa Rowland'...
#
#                                             director                composer  \
# 0                                                NaN                     NaN
# 1                                  ['Steve Purcell']                     NaN
# 2                              ['Yasuhiro Horiuchi']         ['Carole King']
# 3  ['William Arntz', 'Betsy Chasse', 'Mark Vicente']  ['Christopher Franke']
# 4                                    ['Eric Louzil']         ['Bob Mithoff']
#
#                                               writer  runtime
# 0   ['Mike Carrol', 'Mike Carroll', 'Georgann Kane']     50.0
# 1                                                NaN     83.0
# 2  ['Kazumasa Hirai', 'Jirô Kuwata', 'Junko Suzuki']      NaN
# 3  ['William Arntz', 'Betsy Chasse', 'Matthew Hof...     60.0
# 4     ['Lloyd Kaufman', 'Carl Morano', 'Matt Unger']     96.0

# %%
# print out the length of this dataframe
len(df)
# Out:
# 8451

# %%
# analyze the statistics of this dataframe
df.describe()
# Out:
#              index         year       rating          vote      runtime
# count  8451.000000  8451.000000  8135.000000  8.135000e+03  6798.000000
# mean   4225.000000  1991.626080     6.680000  1.873295e+04    99.984113
# std    2439.737896    15.129001     1.281778  8.957999e+04    65.277725
# min       0.000000  1905.000000     1.500000  5.000000e+00     2.000000
# 25%    2112.500000  1987.000000     6.000000  3.075000e+02    82.000000
# 50%    4225.000000  1998.000000     6.900000  1.531000e+03    95.000000
# 75%    6337.500000  2002.000000     7.600000  6.897500e+03   110.000000
# max    8450.000000  2005.000000     9.600000  2.462087e+06  1620.000000

# %%
# check how many null values your dataframe contains using "info()"
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8451 entries, 0 to 8450
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   index     8451 non-null   int64
#  1   title     8451 non-null   object
#  2   year      8451 non-null   int64
#  3   kind      8451 non-null   object
#  4   genre     8384 non-null   object
#  5   rating    8135 non-null   float64
#  6   vote      8135 non-null   float64
#  7   country   8152 non-null   object
#  8   language  8052 non-null   object
#  9   cast      8280 non-null   object
#  10  director  7140 non-null   object
#  11  composer  5722 non-null   object
#  12  writer    7204 non-null   object
#  13  runtime   6798 non-null   float64
# dtypes: float64(3), int64(2), object(9)
# memory usage: 924.5+ KB

# %%
# drop all null values inplace
clean_df =df.dropna()
print(df.dropna)
# Out:
# <bound method DataFrame.dropna of       index                                              title  year  \
# 0         0                                    Dinosaur Planet  2003
# 1         1                                  Get Up and Dance!  1994
# 2         2                                              8 Man  1992
# 3         3                       What the #$*! Do We (K)now!?  2004
# 4         4  Class of Nuke 'Em High Part II: Subhumanoid Me...  1991
# ...     ...                                                ...   ...
# 8446   8446                                All Monsters Attack  1969
# 8447   8447                                       Fidel Castro  2005
# 8448   8448                                              Epoch  2001
# 8449   8449                                        The Company  2003
# 8450   8450                                           Predator  1987
#
#                 kind                                              genre  \
# 0     tv mini series             ['Documentary', 'Animation', 'Family']
# 1        video movie                                         ['Family']
# 2              movie                               ['Action', 'Sci-Fi']
# 3              movie  ['Documentary', 'Comedy', 'Drama', 'Fantasy', ...
# 4              movie                     ['Comedy', 'Horror', 'Sci-Fi']
# ...              ...                                                ...
# 8446           movie                 ['Adventure', 'Family', 'Fantasy']
# 8447         episode            ['Documentary', 'Biography', 'History']
# 8448        tv movie                             ['Sci-Fi', 'Thriller']
# 8449           movie                      ['Drama', 'Music', 'Romance']
# 8450           movie      ['Action', 'Adventure', 'Sci-Fi', 'Thriller']
#
#       rating      vote                                         country  \
# 0        7.7     474.0                               ['United States']
# 1        8.1      18.0                               ['United States']
# 2        5.5      93.0                                       ['Japan']
# 3        5.3   13432.0                               ['United States']
# 4        4.5    2177.0                               ['United States']
# ...      ...       ...                                             ...
# 8446     3.9    4384.0                                       ['Japan']
# 8447     6.4      44.0                                             NaN
# 8448     4.9    2376.0                               ['United States']
# 8449     6.3    6501.0  ['United States', 'Germany', 'United Kingdom']
# 8450     7.8  386850.0                     ['United States', 'Mexico']
#
#                                language  \
# 0                           ['English']
# 1                           ['English']
# 2                          ['Japanese']
# 3      ['English', 'German', 'Spanish']
# 4                           ['English']
# ...                                 ...
# 8446                       ['Japanese']
# 8447             ['English', 'Spanish']
# 8448                        ['English']
# 8449                        ['English']
# 8450  ['English', 'Spanish', 'Russian']
#
#                                                    cast  \
# 0                 ['Christian Slater', 'Scott Sampson']
# 1     ['Paula Abdul', 'Aurorah Allain', 'Bill Bohl',...
# 2     ['Kai Shishido', 'Etsushi Takahashi', 'Sachiko...
# 3     ['Marlee Matlin', 'Elaine Hendrix', 'John Ross...
# 4     ['Brick Bronsky', 'Lisa Gaye', 'Leesa Rowland'...
# ...                                                 ...
# 8446  ['Tomonori Yazaki', 'Hideyo Amamoto', 'Sachio ...
# 8447  ['Rena Baskin', 'Fulgencio Batista', 'James Bl...
# 8448  ['David Keith', 'Stephanie Niznik', "Ryan O'Ne...
# 8449  ['Neve Campbell', 'Malcolm McDowell', 'James F...
# 8450  ['Arnold Schwarzenegger', 'Carl Weathers', 'El...
#
#                                                director  \
# 0                                                   NaN
# 1                                     ['Steve Purcell']
# 2                                 ['Yasuhiro Horiuchi']
# 3     ['William Arntz', 'Betsy Chasse', 'Mark Vicente']
# 4                                       ['Eric Louzil']
# ...                                                 ...
# 8446   ['Ishirô Honda', 'Jun Fukuda', 'Kengo Furusawa']
# 8447            ['Adriana Bosch', 'M Pink Christofalo']
# 8448                                      ['Matt Codd']
# 8449                                  ['Robert Altman']
# 8450                                 ['John McTiernan']
#
#                     composer  \
# 0                        NaN
# 1                        NaN
# 2            ['Carole King']
# 3     ['Christopher Franke']
# 4            ['Bob Mithoff']
# ...                      ...
# 8446      ['Kunio Miyauchi']
# 8447        ['Mason Daring']
# 8448      ['Richard McHugh']
# 8449      ['Van Dyke Parks']
# 8450      ['Alan Silvestri']
#
#                                                  writer  runtime
# 0      ['Mike Carrol', 'Mike Carroll', 'Georgann Kane']     50.0
# 1                                                   NaN     83.0
# 2     ['Kazumasa Hirai', 'Jirô Kuwata', 'Junko Suzuki']      NaN
# 3     ['William Arntz', 'Betsy Chasse', 'Matthew Hof...     60.0
# 4        ['Lloyd Kaufman', 'Carl Morano', 'Matt Unger']     96.0
# ...                                                 ...      ...
# 8446                             ["Shin'ichi Sekizawa"]      NaN
# 8447                                  ['Adriana Bosch']      NaN
# 8448  ['Jonathan Raymond', 'Jonathan Raymond', 'Phil...      NaN
# 8449  ['Neve Campbell', 'Barbara Turner', 'Barbara T...      NaN
# 8450                      ['Jim Thomas', 'John Thomas']      NaN
#
# [8451 rows x 14 columns]>

# %%
# print out the length of this dataframe after this drop
len(clean_df)
# Out:
# 4133

# %%
# filter this data to only include rows where years are after 1990
clean_df.head()
(df[df["year"]>1990])
# Out:
#       index                                              title  year  \
# 3         3                       What the #$*! Do We (K)now!?  2004
# 4         4  Class of Nuke 'Em High Part II: Subhumanoid Me...  1991
# 7         7                                          7 Seconds  2005
# 10       10                                  Strange Relations  2001
# 12       12                                            Boycott  2001
# ...     ...                                                ...   ...
# 7251   7251                                   The Art of Dying  1991
# 7252   7252                                     Demolition Man  1993
# 7258   7258                                      Frozen Impact  2003
# 7261   7261                                              Shade  2003
# 7262   7262                                Nothing But Trouble  1991
#
#              kind                                              genre  rating  \
# 3           movie  ['Documentary', 'Comedy', 'Drama', 'Fantasy', ...     5.3
# 4           movie                     ['Comedy', 'Horror', 'Sci-Fi']     4.5
# 7     video movie          ['Action', 'Comedy', 'Crime', 'Thriller']     4.8
# 10       tv movie                                ['Drama', 'Comedy']     7.6
# 12       tv movie                               ['Drama', 'History']     7.2
# ...           ...                                                ...     ...
# 7251        movie                              ['Crime', 'Thriller']     4.7
# 7252        movie                   ['Action', 'Sci-Fi', 'Thriller']     6.7
# 7258     tv movie                   ['Drama', 'Romance', 'Thriller']     3.8
# 7261        movie                              ['Crime', 'Thriller']     6.3
# 7262        movie                                         ['Comedy']     5.1
#
#           vote                                            country  \
# 3      13432.0                                  ['United States']
# 4       2177.0                                  ['United States']
# 7       7153.0  ['United Kingdom', 'Romania', 'Switzerland', '...
# 10       768.0                ['United Kingdom', 'United States']
# 12       901.0                                  ['United States']
# ...        ...                                                ...
# 7251     267.0                                  ['United States']
# 7252  165860.0                                  ['United States']
# 7258     462.0                                  ['United States']
# 7261   12485.0                                  ['United States']
# 7262   23598.0                                  ['United States']
#
#                               language  \
# 3     ['English', 'German', 'Spanish']
# 4                          ['English']
# 7                          ['English']
# 10                         ['English']
# 12                         ['English']
# ...                                ...
# 7251                       ['English']
# 7252                       ['English']
# 7258                       ['English']
# 7261                       ['English']
# 7262                       ['English']
#
#                                                    cast  \
# 3     ['Marlee Matlin', 'Elaine Hendrix', 'John Ross...
# 4     ['Brick Bronsky', 'Lisa Gaye', 'Leesa Rowland'...
# 7     ['Wesley Snipes', 'Tamzin Outhwaite', 'Deobia ...
# 10    ['Paul Reiser', 'Amber Sealey', 'Lachele Carl'...
# 12    ['Jeffrey Wright', 'Terrence Howard', 'CCH Pou...
# ...                                                 ...
# 7251  ['Wings Hauser', 'Kathleen Kinmont', 'Gary Wer...
# 7252  ['Sylvester Stallone', 'Wesley Snipes', 'Sandr...
# 7258  ['Ted McGinley', 'Linda Purl', 'Stacy Keach', ...
# 7261  ['Joe Nicolo', 'Carl Mazzocone Sr.', 'George T...
# 7262  ['Chevy Chase', 'Dan Aykroyd', 'John Candy', '...
#
#                                                director  \
# 3     ['William Arntz', 'Betsy Chasse', 'Mark Vicente']
# 4                                       ['Eric Louzil']
# 7                                     ['Simon Fellows']
# 10                                        ['Paul Seed']
# 12                                    ['Clark Johnson']
# ...                                                 ...
# 7251                                   ['Wings Hauser']
# 7252                                ['Marco Brambilla']
# 7258                                  ['Neil Kinsella']
# 7261                                  ['Damian Nieman']
# 7262                                    ['Dan Aykroyd']
#
#                             composer  \
# 3             ['Christopher Franke']
# 4                    ['Bob Mithoff']
# 7     ['Barry Taylor', 'Neal Acree']
# 10       ['Rupert Gregson-Williams']
# 12              ['Joseph Vitarelli']
# ...                              ...
# 7251               ['John Gonzalez']
# 7252           ['Elliot Goldenthal']
# 7258               ['James T. Sale']
# 7261               ['James Johnzen']
# 7262               ['Michael Kamen']
#
#                                                  writer  runtime
# 3     ['William Arntz', 'Betsy Chasse', 'Matthew Hof...     60.0
# 4        ['Lloyd Kaufman', 'Carl Morano', 'Matt Unger']     96.0
# 7                                    ['Martin Wheeler']    118.0
# 10                                   ['Tim Kazurinsky']     75.0
# 12    ['Stewart Burns', 'Herman Daniel Farrell', 'Ti...     87.0
# ...                                                 ...      ...
# 7251                                   ['Joseph Merhi']    101.0
# 7252  ['Peter M. Lenkov', 'Robert Reneau', 'Daniel W...    107.0
# 7258                                    ['Scott Brown']     88.0
# 7261                                  ['Damian Nieman']    106.0
# 7262                   ['Peter Aykroyd', 'Dan Aykroyd']     92.0
#
# [2758 rows x 14 columns]

# %%
# print out the first 5 rows of this filtered dataframe
clean_df.head(5)
# Out:
#    index                                              title  year  \
# 3      3                       What the #$*! Do We (K)now!?  2004
# 4      4  Class of Nuke 'Em High Part II: Subhumanoid Me...  1991
# 7      7                                          7 Seconds  2005
# 8      8                              By Dawn's Early Light  1990
# 9      9                                    Seeta Aur Geeta  1972
#
#           kind                                              genre  rating  \
# 3        movie  ['Documentary', 'Comedy', 'Drama', 'Fantasy', ...     5.3
# 4        movie                     ['Comedy', 'Horror', 'Sci-Fi']     4.5
# 7  video movie          ['Action', 'Comedy', 'Crime', 'Thriller']     4.8
# 8     tv movie                    ['Action', 'Drama', 'Thriller']     7.1
# 9        movie  ['Adventure', 'Comedy', 'Drama', 'Family', 'Mu...     6.8
#
#       vote                                            country  \
# 3  13432.0                                  ['United States']
# 4   2177.0                                  ['United States']
# 7   7153.0  ['United Kingdom', 'Romania', 'Switzerland', '...
# 8   2898.0                                  ['United States']
# 9   1818.0                                          ['India']
#
#                            language  \
# 3  ['English', 'German', 'Spanish']
# 4                       ['English']
# 7                       ['English']
# 8            ['English', 'Russian']
# 9                         ['Hindi']
#
#                                                 cast  \
# 3  ['Marlee Matlin', 'Elaine Hendrix', 'John Ross...
# 4  ['Brick Bronsky', 'Lisa Gaye', 'Leesa Rowland'...
# 7  ['Wesley Snipes', 'Tamzin Outhwaite', 'Deobia ...
# 8  ['Powers Boothe', 'Rebecca De Mornay', 'James ...
# 9  ['Dharmendra', 'Sanjeev Kumar', 'Hema Malini',...
#
#                                             director  \
# 3  ['William Arntz', 'Betsy Chasse', 'Mark Vicente']
# 4                                    ['Eric Louzil']
# 7                                  ['Simon Fellows']
# 8                                   ['Jack Sholder']
# 9                                   ['Ramesh Sippy']
#
#                          composer  \
# 3          ['Christopher Franke']
# 4                 ['Bob Mithoff']
# 7  ['Barry Taylor', 'Neal Acree']
# 8                ['Trevor Jones']
# 9            ['Rahul Dev Burman']
#
#                                               writer  runtime
# 3  ['William Arntz', 'Betsy Chasse', 'Matthew Hof...     60.0
# 4     ['Lloyd Kaufman', 'Carl Morano', 'Matt Unger']     96.0
# 7                                 ['Martin Wheeler']    118.0
# 8              ['William Prochnau', 'Bruce Gilbert']     58.0
# 9  ['Javed Akhtar', 'Javed Akhtar', 'Satish Bhatn...     15.0

# %%
# print out the length of this dataframe
len(df)
# Out:
# 4133

# %%
# group your dataframe into seperate groups according to "kind"
clean_df.sort_values("kind")
# Out:
#       index                                              title  year  \
# 4164   4164           Rod Serling: Submitted for Your Approval  1995
# 4518   4518                                   A Saintly Switch  1999
# 5441   5441  The Battle of the Bulge: World War II's Deadli...  1994
# 2120   2120                              Death of a Hollow Man  1998
# 5983   5983              Robert Rauschenberg: Inventive Genius  1999
# ...     ...                                                ...   ...
# 1119   1119              The True Story of Alexander the Great  2005
# 1115   1115                                   Green Legend Ran  1992
# 1114   1114             3-2-1 Penguins: The Doom Funnel Rescue  2002
# 4356   4356                                           Deathbed  2002
# 5641   5641                            Pokémon: Mewtwo Returns  2000
#
#              kind                                              genre  rating  \
# 4164      episode                       ['Documentary', 'Biography']     7.3
# 4518      episode  ['Adventure', 'Comedy', 'Drama', 'Family', 'Fa...     5.4
# 5441      episode            ['Documentary', 'Biography', 'History']     8.2
# 2120      episode                      ['Crime', 'Drama', 'Mystery']     7.4
# 5983      episode                       ['Documentary', 'Biography']     5.9
# ...           ...                                                ...     ...
# 1119  video movie  ['Documentary', 'Biography', 'Drama', 'History...     7.6
# 1115  video movie        ['Animation', 'Drama', 'Fantasy', 'Sci-Fi']     7.0
# 1114  video movie  ['Animation', 'Short', 'Adventure', 'Comedy', ...     7.0
# 4356  video movie                                         ['Horror']     3.4
# 5641  video movie  ['Animation', 'Action', 'Adventure', 'Drama', ...     6.5
#
#         vote                              country  \
# 4164   221.0                    ['United States']
# 4518   405.0                    ['United States']
# 5441    95.0                    ['United States']
# 2120  1008.0                   ['United Kingdom']
# 5983    77.0                    ['United States']
# ...      ...                                  ...
# 1119   105.0  ['United States', 'United Kingdom']
# 1115   310.0                            ['Japan']
# 1114    38.0          ['United States', 'Canada']
# 4356   551.0                    ['United States']
# 5641  3505.0                            ['Japan']
#
#                                      language  \
# 4164                              ['English']
# 4518                              ['English']
# 5441                              ['English']
# 2120                              ['English']
# 5983                              ['English']
# ...                                       ...
# 1119  ['Greek, Ancient (to 1453)', 'English']
# 1115                             ['Japanese']
# 1114                              ['English']
# 4356                              ['English']
# 5641                             ['Japanese']
#
#                                                    cast  \
# 4164  ['Lee Grant', 'Rod Serling', 'Mitchell Greenbe...
# 4518  ['Vivica A. Fox', 'David Alan Grier', 'Al Waxm...
# 5441  ['David McCullough', 'Guy Franz Arend', 'Omar ...
# 2120  ['John Nettles', 'Daniel Casey', 'Jane Wymark'...
# 5983           ['Dennis Hopper', 'Robert Rauschenberg']
# ...                                                 ...
# 1119  ['Peter Woodward', 'Rafael Ferrer', 'Michael C...
# 1115  ['Jason Gray-Stanford', 'Janyse Jaud', 'Takesh...
# 1114  ['Mark Marten', 'Melissa Peterson', 'Kymberly ...
# 4356  ['Tanya Dempsey', 'Brave Matthews', 'Joe Estev...
# 5641  ['Veronica Taylor', 'Rachael Lillis', 'Eric St...
#
#                    director  \
# 4164         ['Susan Lacy']
# 4518  ['Peter Bogdanovich']
# 5441      ['Thomas Lennon']
# 2120  ['Jeremy Silberston']
# 5983       ['Karen Thomas']
# ...                     ...
# 1119        ['Jim Lindsay']
# 1115       ['Satoshi Saga']
# 1114          ['Ron Smith']
# 4356       ['Danny Draven']
# 5641   ['Masamitsu Hidaka']
#
#                                                composer  \
# 4164                                  ['Thomas Wagner']
# 4518                              ['Terence Blanchard']
# 5441                                    ['Brian Keane']
# 2120                                     ['Jim Parker']
# 5983                                  ['Peter Melnick']
# ...                                                 ...
# 1119                        ['Michael Richard Plowman']
# 1115                             ['Yôichiro Yoshikawa']
# 1114                                ['Andrea Saparoff']
# 4356                                  ['James T. Sale']
# 5641  ['Kenneth Lampl', 'Shinji Miyazaki', 'Ralph Sc...
#
#                                                  writer  runtime
# 4164                  ['John F. Goff', 'Thomas Wagner']     60.0
# 4518                   ['Sally Hampton', 'Haris Orkin']    100.0
# 5441                ['Thomas Lennon', 'Mark Zwonitzer']    115.0
# 2120  ['Caroline Graham', 'Caroline Graham', 'Peter ...     84.0
# 5983                                   ['Karen Thomas']    113.0
# ...                                                 ...      ...
# 1119                                    ['Jim Lindsay']     97.0
# 1115  ['Hisashi Ezura', 'Kengo Inagaki', 'Kazuyuki M...    120.0
# 1114     ['Cydne Clark', 'Steve Granat', 'Cydne Clark']     94.0
# 4356                   ['George Barry', 'John Strysik']     86.0
# 5641               ['Michael Haigney', 'Takeshi Shudo']    101.0
#
# [4133 rows x 14 columns]

# %%
# print out all your media groups
media_groups=list(clean_df["kind"].tolist())
print(media_groups)
# Out:
# ['movie', 'movie', 'video movie', 'tv movie', 'movie', 'tv movie', 'tv movie', 'video movie', 'movie', 'movie', 'movie', 'video movie', 'movie', 'movie', 'movie', 'movie', 'movie', 'movie', 'tv movie', 'video movie', 'movie', 'movie', 'movie', 'movie', 'movie', 'video movie', 'movie', 'movie', 'movie', 'movie', 'video movie', 'movie', 'movie', 'movie', 'movie', 'tv movie', 'movie', 'movie', 'video movie', 'movie', 'movie', 'tv movie', 'episode', 'movie', 'movie', 'video movie', 'movie', 'episode', 'video movie', 'movie', 'movie', 'movie', 'video movie', 'movie', 'tv movie', 'video movie', 'movie', 'tv movie', 'tv movie', 'movie', 'movie', 'tv movie', 'movie', 'tv movie', 'video movie', 'movie', 'movie', 'movie', 'movie', 'movie', 'movie', 'movie', 'movie', 'tv movie', 'movie', 'movie', 'movie', 'movie', 'movie', 'movie', 'movie', 'movie', 'movie', 'movie', 'movie', 'movie', 'tv movie', 'movie', 'tv movie', 'movie', 'video movie', 'movie', 'movie', 'movie', 'tv movie', 'movie', 'episode', 'movie', 'movie', 'movie', 'movie', 'tv movie', 'movie', 'movie', 'movie', 'movie', 'tv movie', 'movie', 'movie', 'movie', 'tv movie', 'movie', 'movie', 'movie', 'movie', 'movie', 'movie', 'movie', 'tv movie', 'tv movie', 'movie', 'movie', 'movie', 'movie', 'movie', 'movie', 'movie', 'movie', 'tv movie', 'movie', 'tv movie', 'movie', 'tv movie', 'movie', 'movie', 'tv movie', 'tv movie', 'tv movie', 'movie', 'movie', 'movie', 'movie', 'movie', 'movie', 'tv movie', 'movie', 'movie', 'movie', 'tv movie', 'movie', 'movie', 'movie', 'movie', 'movie', 'video movie', 'movie', 'movie', 'movie', 'movie', 'movie', 'movie', 'movie', 'movie', 'movie', 'movie', 'movie', 'video movie', 'episode', 'movie', 'movie', 'video movie', 'movie', 'tv movie', 'movie', 'movie', 'movie', 'tv movie', 'movie', 'movie', 'movie', 'movie', 'movie', 'episode', 'movie', 'movie', 'tv movie', 'movie', 'movie', 'movie', 'tv movie', 'movie', 'movie', 'tv movie', 'tv movie', 'episode', 'movie', 'movie', 'movie', 'movie', 'movie', 'tv movie', 'movie', 'movie', 'movie', 'movie', 'movie', 'movie', 'movie', 'tv movie', 'movie', 'movie', 'movie', 'tv movie', 'movie', 'video movie', 'movie', 'movie', 'movie', 'episode', 'movie', 'movie', 'tv movie', 'movie', 'movie', 'movie', 'movie', 'movie', 'movie', 'movie', 'movie', 'movie', 'episode', 'tv movie', 'tv movie', 'tv movie', 'video movie', 'movie', 'movie', 'movie', 'movie', 'video movie', 'movie', 'movie', 'movie', 'movie', 'video movie', 'movie', 'movie', 'movie', 'tv movie', 'movie', 'movie', 'movie', 'movie', 'movie', 'tv movie', 'movie', 'movie', 'movie', 'movie', 'movie', 'movie', 'tv movie', 'movie', 'movie', 'movie', 'video movie', 'movie', 'movie', 'movie', 'video movie', 'movie', 'movie', 'movie', 'tv movie', 'movie', 'movie', 'movie', 'episode', 'movie', 'video movie', 'video movie', 'movie', 'movie', 'movie', 'movie', 'movie', 'movie', 'video movie', 'video movie', 'movie', 'movie', 'movie', 'episode', 'tv movie', 'movie', 'tv movie', 'tv movie', 'tv movie', 'movie', 'movie', 'movie', 'movie', 'movie', 'movie', 'movie', 'video movie', 'tv movie', 'tv movie', 'tv movie', 'movie', 'movie', 'movie', 'movie', 'tv movie', 'movie', 'video movie', 'video movie', 'movie', 'movie', 'video movie', 'video movie', 'movie', 'movie', 'tv movie', 'movie', 'video movie', 'movie', 'movie', 'movie', 'movie', 'movie', 'movie', 'movie', 'tv movie', 'movie', 'movie', 'movie', 'movie', 'movie', 'movie', 'video movie', 'video movie', 'movie', 'movie', 'tv movie', 'tv movie', 'movie', 'video movie', 'tv movie', 'movie', 'tv movie', 'episode', 'movie', 'movie', 'movie', 'movie', 'movie', 'movie', 'episode', 'movie', 'movie', 'movie', 'movie', 'movie', 'tv movie', 'tv movie', 'movie', 'movie', 'movie', 'movie', 'movie', 'movie', 'movie', 'movie', 'tv movie', 'episode', 'movie', 'tv movie', 'movie', 'tv movie', 'movie', 'video movie', 'movie', 'movie', 'movie', 'movie', 'movie', 'video movie', 'movie', 'movie', 'movie', 'movie', 'movie', 'movie', 'tv  ...

# %%
# calculate the mean rating of each group
means = clean_df.groupby("kind")["rating"].mean()
means .plot.bar()

# plot this dataframe of mean ratings as a bar-graph
# Out:
# <AxesSubplot: xlabel='kind'>

# %%
# calculate the mean runtime of each group
means = clean_df.groupby("kind")["runtime"].mean()
means.plot.bar()

# plot this dataframe of mean runtime as a bar-graph
# Out:
# <AxesSubplot: xlabel='kind'>

# %% [markdown]
# ## Q1
#
# Which media type has the highest mean ranking?
#
# - shorts

# %% [markdown]
# ## Q2
#
# Which media type has the lowest mean ranking?
#
# - Video Movies

# %% [markdown]
# ## Q3
#
# Which media type has the highest mean runtime?
#
# - Video Game

# %% [markdown]
# ## Q4
#
#
# Which media type has the lowest mean runtime?
#
# - TV Short

# %% [markdown]
# ## Challenge
#
# Transform your column `genre` into multiple columns, where `1` indicates presnce of this genre.
#
# Read more about this setup here: https://machinelearningmastery.com/why-one-hot-encode-data-in-machine-learning/
#
# Utilize stackoverflow and the internet to solve this challenge
